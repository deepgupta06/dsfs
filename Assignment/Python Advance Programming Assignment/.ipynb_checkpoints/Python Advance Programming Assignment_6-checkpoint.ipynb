# %% [markdown]
# # Python Advance Programming Assignment_6

# %% [markdown]
# ### 1. You are given two strings s and t. String t is generated by randomly shuffling string s and then adding one more letter at a random position. Return the letter that was added to t.
#
# Examples
#
# find_the_difference("abcd", "abcde") ➞ "e"
#
# find_the_difference("", "y") ➞ "y"
#
# find_the_difference("ae", "aea") ➞ "a"

# %%
s = "deep"
t = "deepg"

# %%
def find_the_difference(s, t):
    result = [x for x in t if x not in s]
    return result[0]

# %%
find_the_difference("", "y")
# Out:
# 'y'

# %%
find_the_difference("abcd", "deacb")
# Out:
# 'e'

# %%
find_the_difference("abcd", "abcde")
# Out:
# 'e'

# %% [markdown]
# ### 2. Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. Finally return the total in a list.
#
# List order is:
#
# [int, str, bool, list, tuple, dictionary]
#
# Examples
#
# count_datatypes(1, 45, "Hi", False) ➞ [2, 1, 1, 0, 0, 0]
#
# count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1) ➞ [3, 0, 0, 1, 1, 0]
#
# count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23) ➞ [2, 2, 3, 1, 0, 2]
#
# count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6]) ➞ [2, 0, 1, 2, 2, 0]

# %%
def count_datatypes(*args):
    data_type_list = [int, str, bool, list, tuple, dict]
    count_list = [0]*len(data_type_list)
    #args = [1,"2",True, True]
    temp_list = [None]*len(args)
    for idx, item in enumerate(args):
        temp_list[idx] = type(item)
    for idx, d_type in enumerate(data_type_list):
        count_list[idx] = temp_list.count(d_type)
    return count_list

# %%
count_datatypes(1, 45, "Hi", False)
# Out:
# [2, 1, 1, 0, 0, 0]

# %%
count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)
# Out:
# [3, 0, 0, 1, 1, 0]

# %%
count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23)
# Out:
# [2, 2, 3, 1, 0, 2]

# %%
count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])
# Out:
# [2, 0, 1, 2, 2, 0]

# %% [markdown]
# ### 3. A Fibonacci string is a precedence of the Fibonacci series. It works with any two characters of the English alphabet (as opposed to the numbers 0 and 1 in the Fibonacci series) as the initial items and concatenates them together as it progresses in a similar fashion as the Fibonacci series.
#
# Examples
#
# fib_str(3, ["j", "h"]) ➞ "j, h, hj"
#
# fib_str(5, ["e", "a"]) ➞ "e, a, ae, aea, aeaae"
#
# fib_str(6, ["n", "k"]) ➞ "n, k, kn, knk, knkkn, knkknknk"

# %%
def fib_str(nth_term, initial_sequence ):
    assert type(nth_term) == int, f"nth_term should be an integer insted of {type(nth_term)}"
    assert type(initial_sequence)==list and len(initial_sequence)==2, f"{initial_sequence} is not list of 2 characters"
    for i in range(0,nth_term-2):
        number = initial_sequence[i+1]+initial_sequence[i]
        initial_sequence.append(number)
    return ", ".join(initial_sequence)

# %%
fib_str(3, ["j", "h"])
# Out:
# 'j, h, hj'

# %%
fib_str(5, ["e", "a"])
# Out:
# 'e, a, ae, aea, aeaae'

# %%
fib_str(6, ["n", "k"])
# Out:
# 'n, k, kn, knk, knkkn, knkknknk'

# %%
fib_str(6, ["n"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-72-1158785822a4> in <module>
# ----> 1 fib_str(6, ["n"])
#
# <ipython-input-68-667006cd47b8> in fib_str(nth_term, initial_sequence)
#       1 def fib_str(nth_term,initial_sequence ):
#       2     assert type(nth_term) == int, f"nth_term should be an integer insted of {type(nth_term)}"
# ----> 3     assert type(initial_sequence)==list and len(initial_sequence)==2, f"{initial_sequence} is not list of 2 characters"
#       4     for i in range(0,nth_term-2):
#       5         number = initial_sequence[i+1]+initial_sequence[i]
#
# AssertionError: ['n'] is not list of 2 characters

# %%
fib_str("lol", ["a"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-e6dc9a3ebd6b> in <module>
# ----> 1 fib_str("lol", ["a"])
#
# <ipython-input-1-d30f67680c37> in fib_str(nth_term, initial_sequence)
#       1 def fib_str(nth_term, initial_sequence ):
# ----> 2     assert type(nth_term) == int, f"nth_term should be an integer insted of {type(nth_term)}"
#       3     assert type(initial_sequence)==list and len(initial_sequence)==2, f"{initial_sequence} is not list of 2 characters"
#       4     for i in range(0,nth_term-2):
#       5         number = initial_sequence[i+1]+initial_sequence[i]
#
# AssertionError: nth_term should be an integer insted of <class 'str'>

# %%
# Out:
# Help on function fib_str in module __main__:
#
# fib_str(nth_term, sequence)
